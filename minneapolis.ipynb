# %%
from data import get_full_acs1_nativity_timeseries
from plotting import plot_acs_timeseries, plot_acs_change
from censusdis.places.minnesota import MINNEAPOLIS_CITY
from censusdis.states import MN

df = get_full_acs1_nativity_timeseries(state=MN, place=MINNEAPOLIS_CITY)
df
# Out:
# ...................
#      Total  Native  Foreign-born  Year
# 0   350260  292800         57460  2005
# 1   369051  314498         54553  2006
# 2   351184  296170         55014  2007
# 3   360914  313673         47241  2008
# 0   385384  326291         59093  2009
# 1   383280  325434         57846  2010
# 2   387736  330636         57100  2011
# 3   392871  335697         57174  2012
# 4   400079  335658         64421  2013
# 5   407181  345197         61984  2014
# 6   410935  340166         70769  2015
# 7   413645  350060         63585  2016
# 8   422326  352759         69567  2017
# 9   425395  357264         68131  2018
# 10  429605  368964         60641  2019
# 11  425338  366988         58350  2021
# 12  425104  362436         62668  2022
# 13  425142  366993         58149  2023
# 14  428572  368895         59677  2024

# %%
plot_acs_timeseries(
    df,
    column="Foreign-born",
    title="Foreign-Born Population in Minneapolis, Minnesota<br>ACS 1-Year Estimates",
    y_label="Population",
)

# %%
plot_acs_change(
    df,
    "Foreign-born",
    "Change in Minneapolis' Foreign-Born Population<br>ACS 1-Year Estimates",
)
